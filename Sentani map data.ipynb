# %%
#For the given code:
#Ive made a table in order to find the ratios of those who were surveyed to the two sets of observational data 
#(an official estimate and my satellite estimate) of the population in the villages of interest. 
#There are four columns:
#Village=village of interest
#Count_official=the count of structures from an official map
#Sat_Count=my own estimate of villages by counting structures in a map (assuming that 1 structure is owned by a person)
#Villaged_Surveyed=the number of surveyed people in this study based on village association.
#Village_Surveyed_to_Official_Ratio=Village_surveyed divided by Official 
#Village_Surveyed_to_Sat_Ratio=Village_Surveyed divided by Sat_Count

# %%
from io import StringIO
import pandas as pd

# %%
Table_1 = '''Village,Official_count,Sat_Count,Village_Surveyed
Abar,40,45,46
Ajau_Evale_Hobong,100,84,56
Asei,40,40,29
Atamali,40,38,35
Ayapo,120,140,120
Babrongko, 65,120,67
Burawai,20,16,8
Donday,50,57,50
Doyo_Lama,N/A,N/A,N/A
Ebunfauw,50,39,36
Flafow,N/A,N/A,N/A
Kalio,40,39,30
Kampung_Baru,25,54,36
Kensio,20,19,19
Khageuw,15,27,16
Khamayakha,50,104,14
Kheleubulow,N/A,N/A,52
Kwadeware,30,27,30
Obolyo,18,18,11
Pantai_Yahim,30,27,13
Puai,60,80,74
Simporo,65,113,62
Sosiri,N/A,N/A,96
Tanjung_Elmo,N/A,N/A,N/A
Yakonde,70,55,59
Yobeh,40,38,34
Yoboi,70,64,49
Yoka,150,193,28
Yokiwa,80,64,43'''

data = pd.read_csv(StringIO(Table_1))
data['Village_Surveyed_to_Official_Ratio'] = data['Village_Surveyed']/data['Official_count']
data['Village_Surveyed_to_Sat_Ratio'] = data['Village_Surveyed']/data['Sat_Count']

# %%
data
# Out:
#               Village  Official_count  Sat_Count  Village_Surveyed  \
# 0                Abar              40         45                46
# 1   Ajau_Evale_Hobong             100         84                56
# 2                Asei              40         40                29
# 3             Atamali              40         38                35
# 4               Ayapo             120        140               120
# 5           Babrongko              65        120                67
# 6             Burawai              20         16                 8
# 7              Donday              50         57                50
# 8           Doyo_Lama             NaN        NaN               NaN
# 9            Ebunfauw              50         39                36
# 10             Flafow             NaN        NaN               NaN
# 11              Kalio              40         39                30
# 12       Kampung_Baru              25         54                36
# ...
